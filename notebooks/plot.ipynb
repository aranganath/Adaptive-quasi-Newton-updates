# %%
import matplotlib.pyplot as plt
import pickle as pkl
import os
os.chdir('..')

# %%
with open('Adam-results.pkl', 'rb') as f:
    a = pkl.load(f)

with open('quasi-Adam-results.pkl', 'rb') as f:
    b = pkl.load(f)

# %%
plt.plot(a, label='Adam')
plt.plot(b, label='quasi-Adam')
