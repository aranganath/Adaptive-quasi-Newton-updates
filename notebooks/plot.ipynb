# %%
import matplotlib.pyplot as plt
import pickle as pkl
import os
os.chdir('..')

# %%
with open('Adam-results.pkl', 'rb') as f:
    a = pkl.load(f)

with open('quasi-Adam-results.pkl', 'rb') as f:
    b = pkl.load(f)

# %%
start = 0
end = -1
plt.plot(a[start:end], label='Adam')
plt.plot(b[start:end], label='quasi-Adam')
# plt.plot(f[start:end], label='quasi-Adam-with-denom')

plt.legend()
plt.savefig('results.png')
plt.show()
